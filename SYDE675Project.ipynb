# %% [markdown]
# #Environment

# %%
# !python3 -m pip install --upgrade pip
# !python3 -m pip install megengine -f https://megengine.org.cn/whl/mge.html

# %% [markdown]
# # Load Data

# %%
# !python /content/drive/MyDrive/675/Project/GitCode/prepare_data.py --data_dir /content/drive/MyDrive/675/Project/datasets/SIDD_Medium_Srgb/Data --tar_dir /content/drive/MyDrive/675/Project/datasets/SIDD_Medium_Srgb/train
# Out:
# Number of big images: 320
# Training: Split the original images to small ones!
# 100% 320/320 [22:02<00:00,  4.13s/it]
# Finish!

# %% [markdown]
# # Implement code of papar

# %%
# !python /content/drive/MyDrive/675/Project/GitCode/train_mge.py -d /content/drive/MyDrive/675/Project/datasets/SIDD_Medium_Srgb/ -n 1 --epochs 20 --steps_per_epoch 1000
# Out:
# 16 1
# 16 2
# 16 3
# 16 4
# 16 18:25:05 Epoch 0 Step 0, Speed=1.4 mb/s, dp_cost=0.48, Loss=4.36e-01, lr=2.00e-04
# 16 18:26:27 Epoch 0 Step 10, Speed=1 mb/s, dp_cost=0.014, Loss=1.55e-01, lr=2.00e-04
# 16 18:26:37 Epoch 0 Step 20, Speed=1.2 mb/s, dp_cost=0.039, Loss=9.41e-02, lr=2.00e-04
# 16 18:26:46 Epoch 0 Step 30, Speed=1.2 mb/s, dp_cost=0.0057, Loss=9.82e-02, lr=2.00e-04
# 16 18:26:55 Epoch 0 Step 40, Speed=1.2 mb/s, dp_cost=0.07, Loss=1.11e-01, lr=2.00e-04
# 16 18:27:05 Epoch 0 Step 50, Speed=1.1 mb/s, dp_cost=0.014, Loss=7.89e-02, lr=2.00e-04
# 16 18:27:13 Epoch 0 Step 60, Speed=1.2 mb/s, dp_cost=0.052, Loss=5.42e-02, lr=2.00e-04
# 16 18:27:23 Epoch 0 Step 70, Speed=0.91 mb/s, dp_cost=0.023, Loss=7.72e-02, lr=2.00e-04
# 16 18:27:32 Epoch 0 Step 80, Speed=1 mb/s, dp_cost=0.013, Loss=9.59e-02, lr=2.00e-04
# 16 18:27:41 Epoch 0 Step 90, Speed=0.88 mb/s, dp_cost=0.012, Loss=5.74e-02, lr=2.00e-04
# ...

# %%
# !python /content/drive/MyDrive/675/Project/GitCode/test.py -d /content/drive/MyDrive/675/Project/datasets/SIDD_Medium_Srgb/ -c /content/output/NBNet/checkpoint.pkl
# Out:
# 16 1
# 16 2
# 16 3
# 16 4
# 0it [00:00, ?it/s]/content/drive/MyDrive/675/Project/GitCode/test.py:42: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:189.)
#   tensor_im_gt = torch.from_numpy(im_gt)
# 899it [02:29,  6.02it/s]
# PSNR: 35.241

# %%
# !zip -r /content/file.zip /content/output
# !unzip /content/file.zip -d /content/drive/MyDrive/675/Project/datasets/outputs/Original
# !mv /content/output /content/drive/MyDrive/675/Project/datasets/outputs/Original

# %% [markdown]
# #Improvement

# %% [markdown]
# 1.   Mod 1 - project upsample

# %%
# !python /content/drive/MyDrive/675/Project/Improvement/train_mge.py -d /content/drive/MyDrive/675/Project/datasets/SIDD_Medium_Srgb -n 1 --epochs 20 --steps_per_epoch 1000

# %%
# !python /content/drive/MyDrive/675/Project/Improvement/test.py -d /content/drive/MyDrive/675/Project/datasets/SIDD_Medium_Srgb -c /content/drive/MyDrive/675/Project/datasets/outputs/x2@/content/output/NBNet/checkpoint.pkl
# Out:
# 0it [00:00, ?it/s]/content/drive/MyDrive/675/Project/Improvement/test.py:42: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:189.)
#   tensor_im_gt = torch.from_numpy(im_gt)
# 899it [02:21,  6.36it/s]
# PSNR: 35.641

# %%
# !zip -r /content/drive/MyDrive/675/Project/file.zip /content/output
# !unzip /content/drive/MyDrive/675/Project/file.zip -d /content/drive/MyDrive/675/Project/datasets/outputs/X2@
# !mv /content/output /content/drive/MyDrive/675/Project/datasets/outputs/X2@

# %% [markdown]
# 2.   Mod 2 - project mean

# %%
# !python /content/drive/MyDrive/675/Project/Improvement/train_mge.py -d /content/drive/MyDrive/675/Project/datasets/SIDD_Medium_Srgb -n 1 --epochs 20 --steps_per_epoch 1000
# Out:
# 17 04:12:53 Epoch 0 Step 0, Speed=0.02 mb/s, dp_cost=0.99, Loss=2.52e-01, lr=2.00e-04
# 17 04:13:45 Epoch 0 Step 10, Speed=1.8 mb/s, dp_cost=0.037, Loss=9.79e-02, lr=2.00e-04
# 17 04:14:38 Epoch 0 Step 20, Speed=1.9 mb/s, dp_cost=0.042, Loss=1.11e-01, lr=2.00e-04
# 17 04:15:31 Epoch 0 Step 30, Speed=1.8 mb/s, dp_cost=0.018, Loss=9.73e-02, lr=2.00e-04
# 17 04:17:02 Epoch 0 Step 40, Speed=0.023 mb/s, dp_cost=1, Loss=6.54e-02, lr=2.00e-04
# 17 04:17:41 Epoch 0 Step 50, Speed=2 mb/s, dp_cost=0.029, Loss=9.16e-02, lr=2.00e-04
# 17 04:18:28 Epoch 0 Step 60, Speed=1.7 mb/s, dp_cost=0.0079, Loss=9.51e-02, lr=2.00e-04
# 17 04:19:18 Epoch 0 Step 70, Speed=1.8 mb/s, dp_cost=0.021, Loss=6.58e-02, lr=2.00e-04
# 17 04:20:43 Epoch 0 Step 80, Speed=0.025 mb/s, dp_cost=1, Loss=7.97e-02, lr=2.00e-04
# 17 04:21:30 Epoch 0 Step 90, Speed=1.8 mb/s, dp_cost=0.041, Loss=9.11e-02, lr=2.00e-04
# 17 04:22:13 Epoch 0 Step 100, Speed=1.7 mb/s, dp_cost=0.017, Loss=8.03e-02, lr=2.00e-04
# ...

# %%
# !python /content/drive/MyDrive/675/Project/Improvement/test.py -d /content/drive/MyDrive/675/Project/datasets/SIDD_Medium_Srgb -c /content/output/NBNet/checkpoint.pkl
# Out:
# 0it [00:00, ?it/s]/content/drive/MyDrive/675/Project/Improvement/test.py:42: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:189.)
#   tensor_im_gt = torch.from_numpy(im_gt)
# 899it [01:58,  7.58it/s]
# PSNR: 35.400

# %%
# !zip -r /content/drive/MyDrive/675/Project/file.zip /content/output
# !unzip /content/drive/MyDrive/675/Project/file.zip -d /content/drive/MyDrive/675/Project/datasets/outputs/mean

# %% [markdown]
# 3.   Mod 3 - project 3:1 and 1:3

# %%
# !python /content/drive/MyDrive/675/Project/Improvement/train_mge.py -d /content/drive/MyDrive/675/Project/datasets/SIDD_Medium_Srgb -n 1 --epochs 20 --steps_per_epoch 1000
# Out:
# 18 00:16:43[mgb] NVRTC JIT: compile jit_nvrtc_a428a364b3db3039 for 7.5: source_len=3835 ptx_len=2418 time=863.606ms
# 18 00:16:45[mgb] NVRTC JIT: compile jit_nvrtc_4285a7a0fe2afdf4 for 7.5: source_len=5792 ptx_len=3258 time=431.520ms
# 18 00:16:45 Epoch 0 Step 0, Speed=0.0062 mb/s, dp_cost=0.99, Loss=1.78e-01, lr=2.00e-04
# 18 00:21:01 Epoch 0 Step 10, Speed=1.1 mb/s, dp_cost=0.024, Loss=6.74e-02, lr=2.00e-04
# 18 00:21:14 Epoch 0 Step 20, Speed=1 mb/s, dp_cost=0.013, Loss=9.94e-02, lr=2.00e-04
# 18 00:21:26 Epoch 0 Step 30, Speed=1 mb/s, dp_cost=0.0083, Loss=5.31e-02, lr=2.00e-04
# 18 00:21:42 Epoch 0 Step 40, Speed=0.3 mb/s, dp_cost=0.97, Loss=7.42e-02, lr=2.00e-04
# 18 00:21:55 Epoch 0 Step 50, Speed=1.1 mb/s, dp_cost=0.058, Loss=7.17e-02, lr=2.00e-04
# 18 00:22:08 Epoch 0 Step 60, Speed=0.92 mb/s, dp_cost=0.0092, Loss=8.08e-02, lr=2.00e-04
# 18 00:22:21 Epoch 0 Step 70, Speed=0.99 mb/s, dp_cost=0.015, Loss=7.36e-02, lr=2.00e-04
# ...

# %%
# !python /content/drive/MyDrive/675/Project/Improvement/test.py -d /content/drive/MyDrive/675/Project/datasets/SIDD_Medium_Srgb -c /content/output/NBNet/checkpoint.pkl
# Out:
# 0it [00:00, ?it/s]/content/drive/MyDrive/675/Project/Improvement/test.py:42: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ../torch/csrc/utils/tensor_numpy.cpp:189.)
#   tensor_im_gt = torch.from_numpy(im_gt)
# 899it [02:17,  6.54it/s]
# PSNR: 35.262

# %%
# !mv /content/output /content/drive/MyDrive/675/Project/datasets/outputs/25B75U
